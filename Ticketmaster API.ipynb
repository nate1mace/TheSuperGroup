# %%
import ticketpy
from config import api_key
# Out:
# 0kcXshaf9onVsM03hkz4uAQ3c05K42gk

# %%
tm_client = ticketpy.ApiClient(api_key)

pages = tm_client.events.find(
    classification_name='Hip-Hop',
    state_code='NY',
    start_date_time='2019-09-19T20:00:00Z',
    end_date_time='2019-12-25T00:00:00Z',
).one()

for event in pages:
    print(event)
# Out:
# Event:            Killy
# Venues:           [<ticketpy.model.Venue object at 0x000002A2516E0488>]
# Start date:       2019-12-03
# Start time:       20:00:00
# Price ranges:     []
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000002A2516E8F88>]
#
# Event:            The Noise Presents ISSUES: THE BEAUTIFUL OBLIVION TOUR
# Venues:           [<ticketpy.model.Venue object at 0x000002A2516E0148>]
# Start date:       2019-12-06
# Start time:       17:30:00
# Price ranges:     [{'min': 29.5, 'max': 40.0}]
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000002A2516E0308>]
#
# Event:            Ski Mask the Slump God
# Venues:           [<ticketpy.model.Venue object at 0x000002A2516E0E48>]
# Start date:       2019-12-06
# Start time:       20:00:00
# Price ranges:     []
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000002A2516E0FC8>]
#
# ...

# %%
print(page)
# Out:
# Event:            Je'Caryous Johnson Presents "Set It Off"
# Venues:           [<ticketpy.model.Venue object at 0x000002A25139BB08>]
# Start date:       2020-02-22
# Start time:       15:00:00
# Price ranges:     [{'min': 35.5, 'max': 95.5}]
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000002A25139B9C8>]
