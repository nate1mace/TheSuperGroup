# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
from cryptoconfig import api_key
from pprint import pprint

# %%
base_url = "https://api.nomics.com/v1/"
markets = "markets"
currencies = "currencies/ticker"
currency = "currencies/sparkline"
market_url = base_url + markets + "?key=" + api_key + "&exchange=binance&base=BTC,ETH,LTC,XMR&quote=BTC,ETH,BNB"
currency_url = base_url + currencies + "?key=" + api_key + "&ids=USDT&interval=1d"
history_url = base_url + currency + "?key=" + api_key + "&start=2018-04-14T00%3A00%3A00Z&end=2018-04-15T00%3A00%3A00Z"

response = requests.get(history_url).json()
pprint(response)
# Out:
# [{'currency': '1ST',
#   'prices': ['0.18990801', '0.30233548'],
#   'timestamps': ['2018-04-14T00:00:00Z', '2018-04-15T00:00:00Z']},
#  {'currency': '2GIVE',
#   'prices': ['0.00711459', '0.00819357'],
#   'timestamps': ['2018-04-14T00:00:00Z', '2018-04-15T00:00:00Z']},
#  {'currency': 'ABT',
#   'prices': ['0.87224331', '0.96255013'],
#   'timestamps': ['2018-04-14T00:00:00Z', '2018-04-15T00:00:00Z']},
#  {'currency': 'ABX',
#   'prices': ['0.20105759', '0.21358328'],
#   'timestamps': ['2018-04-14T00:00:00Z', '2018-04-15T00:00:00Z']},
#  {'currency': 'ABY',
#   'prices': ['0.00751428', '0.00819357'],
#   'timestamps': ['2018-04-14T00:00:00Z', '2018-04-15T00:00:00Z']},
#  {'currency': 'ACAT',
#   'prices': ['0.00602604', '0.00640391'],
#   'timestamps': ['2018-04-14T00:00:00Z', '2018-04-15T00:00:00Z']},
#  {'currency': 'ACC',
#   'prices': ['1.85968970', '1.22810079'],
#   'timestamps': ['2018-04-14T00:00:00Z', '2018-04-15T00:00:00Z']},
#  {'currency': 'ACO',
# ...
