# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

source = 'AirbnbSept19.csv'
df = pd.read_csv(source)

# %%
df['price'] = df['price'].astype(float)
df.dtypes
df
# Out:
#              id                                              name    host_id  \
# 0          3647               THE VILLAGE OF HARLEM....NEW YORK !       4632
# 1          3831                   Cozy Entire Floor of Brownstone       4869
# 2          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 3          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 4          5121                                   BlissArtsSpace!       7356
# ...         ...                                               ...        ...
# 48372  38564068                                 Top Floor Delight  207204450
# 48373  38564524                             Central Park Elegance    1567562
# 48374  38566777                              Quiet room available  159902221
# 48375  38567542              Spacious room in Brooklyn brownstone   68905617
# 48376  38568081         Petrose home by JFK, Beach &St John Hosp.  293596932
#
# ...

# %%
df_neighborhood = df[['neighbourhood_group','neighbourhood','price']]
#df_neighborhood = df_neighborhood.groupby(['neighbourhood_group','neighbourhood']).mean()

df_borough = df_neighborhood.groupby(['neighbourhood_group']).mean().reset_index()

# %%
# df_neighborhood.head()
df_borough.head()
# Out:
#   neighbourhood_group       price
# 0               Bronx   85.787744
# 1            Brooklyn  122.902045
# 2           Manhattan  199.501534
# 3              Queens   99.017769
# 4       Staten Island  118.883008

# %%
# plt.bar(df_neighborhood['neighbourhood'],df_neighborhood['price'])
# df_neighborhood=df_neighborhood.astype(float)
# plot = df_neighborhood.plot.bar(x='price')
plt.figure(figsize=(10,4))
plt.bar(df_borough['neighbourhood_group'],df_borough['price'],)
plt.title("Average Airbnb Cost by NYC Borough, 2019", size = (20))
plt.ylabel("Cost, One Night ($)", size = (16))
plt.xlabel('Borough', size = (16))

plt.savefig("Airbnb Cost NYC 2019")
